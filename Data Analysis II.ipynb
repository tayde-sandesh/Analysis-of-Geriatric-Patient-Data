# %%
import pandas as pd
import numpy as np

# %%
r'C:\Users\Sandesh\Project\Physiotherapy Project\Geriatric Data.xlsx'
# Out:
# 'C:\\Users\\Sandesh\\Project\\Physiotherapy Project\\Geriatric Data.xlsx'

# %%
df = pd.read_excel(r'C:\Users\Sandesh\Project\Physiotherapy Project\Geriatric Data.xlsx')
df
# Out:
#      Sr.No.   Age Gender      Ht     Wt     Address    Med History  \
# 0         1  71.0      M  158.07  71.00  Old Sangvi      AVAILABLE
# 1         2  62.0      F  150.00  72.00  New Sangvi            NaN
# 2         3  68.0      M  158.07  60.00  New Sangvi      AVAILABLE
# 3         4  70.0      M  158.07  62.00  Old Sangvi      AVAILABLE
# 4         5  68.0      M  161.00  63.00  Old Sangvi      AVAILABLE
# ..      ...   ...    ...     ...    ...         ...            ...
# 828     829  67.0      F  153.00  61.00     Bavdhan  NOT AVAILABLE
# 829     830  82.0      M  158.07  64.06     Bavdhan  NOT AVAILABLE
# 830     831  85.0      F  156.00  67.00     Bavdhan  NOT AVAILABLE
# 831     832  74.0      M  163.00  58.00     Bavdhan  NOT AVAILABLE
# 832     833  81.0      F  147.00  60.00     Bavdhan  NOT AVAILABLE
#
#                         Sx History                          Medication  HTN  \
# 0                              NaN                                 NaN  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 0 to 832
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sr.No.       833 non-null    int64
#  1   Age          833 non-null    float64
#  2   Gender       833 non-null    object
#  3   Ht           833 non-null    float64
#  4   Wt           833 non-null    float64
#  5   Address      798 non-null    object
#  6   Med History  352 non-null    object
#  7   Sx History   450 non-null    object
#  8   Medication   342 non-null    object
#  9   HTN          583 non-null    object
#  10  DM           567 non-null    object
#  11  B.P.         720 non-null    object
#  12  Systolic     720 non-null    object
#  13  Diastolic    717 non-null    float64
#  14  GDS          779 non-null    float64
#  15  MOCA         781 non-null    float64
#  16  PEFR 2       489 non-null    object
#  17  MWT          606 non-null    float64
# ...

# %%
df['Systolic'].unique()
# Out:
# array([120, 110, 176, 161, 135, 204, 119, 156, 165, 178, 136, 150, 155,
#        151, 153, 199, 133, 157, 159, 167, 146, 126, 122, 179, 148, 117,
#        128, 158, 143, 162, 152, 132, 124, 180, 147, 166, nan, 123, 149,
#        144, 141, 142, 137, 107, 138, 118, 160, 114, 125, 109, 145, 197,
#        170, 187, 194, 113, 116, 169, 140, 115, 183, 93, 154, 198, 193,
#        163, 189, 134, 139, 131, 173, 127, 186, 130, 101, 129, 103, 112,
#        106, 172, 168, 121, 171, 111, 184, 175, 185, 104, '  ', 182, 213,
#        177, 174, 102, 164, 105, 108, 100, 196, 188, 181, 208],
#       dtype=object)

# %%
df['Systolic'].replace({'  ':None},inplace=True)

# %%
df['Systolic'] = df['Systolic'].astype(float)

# %%
df['PEFR 2'].unique()
# Out:
# array([240, 200, 250, 400, 150, 280, nan, 350, 370, 270, 300, 340, 120,
#        80, 100, 180, 450, 320, 500, 325, 230, 330, 210, 600, 550, 175,
#        160, 225, 420, 95, 352, 170, 109, 60, 310, 470, 430, 390, 410, 380,
#        220, 110, 190, 260, ' ', 112, 137, 42, 81, 34, 58, 50, 65, 94, 41,
#        31, 64, 36, 74, 46, 49, 28, 35, 45, 6, 145, 70, 54, 90, 76, 118],
#       dtype=object)

# %%
df['PEFR 2'] = df['PEFR 2'].astype(float)

# %%
df['FRT'].unique()
# Out:
# array([nan, 41.5, 23, 22.5, 25, 16, 10, 19.5, 33, 13.7, 14, 24.7, 32.4,
#        25.8, 16.7, 17.5, 27.9, 27.3, 22.9, 29.5, 32.2, 16.2, 26.7, 28,
#        13.4, 22.7, 38.4, 28.8, 39.5, 27.4, 34.4, 45, 30.9, 19.4, 32, 28.6,
#        30.2, 26, 27, 40.2, 24.4, 16.8, 49, 38, 35, 36, 53, 20, 44, 30, 21,
#        24, 22, 34, 40, 52, 18, 31, 12, 19, 13, 29, 15, 14.5, 16.5, 18.5,
#        15.5, 13.5, 7, 11, 17, 12.5, 15.7, 8, 14.8, 9, 43, 50, 39, 51, 37,
#        48, 41, 47, 26.9, '  ', 42, 46, 55, 6, 3, 5, 4, 8.5, 7.75, 8.75,
#        7.5, 8.25, 4.75, 15.875, 21.59, 19.685, 12.065, 15.24, 12.7, 9.8,
#        11.9, 15.6, 15.8, 8.9, 9.12, 9.2, 10.8, 14.4, 11.5, 14.1, 6.89,
#        11.1, 9.5, 2, 7.8, 6.6, 6.2, 5.5, 8.4, 4.5, 6.5, 10.5, 17.78,
#        30.48, 22.86, 27.94, 20.32, 40.64, 24.13, 5.4, 25.4, 9.1, 10.1,
#        11.8, 4.9, 4.6, 12.8], dtype=object)

# %%
df.replace({'  ':None},inplace=True)

# %%
df['FRT'] = df['FRT'].astype(float)

# %%
df['TMT A'] = df['TMT A'].astype(float)

# %%
df['TMT A'].unique()
# Out:
# array([   nan,  46.  ,  26.9 ,  60.6 ,  63.3 ,  39.2 ,  28.8 ,  49.7 ,
#         59.2 ,  50.  ,  43.  ,  76.  ,  33.  ,  28.  ,  74.  ,  56.  ,
#         32.  ,  35.  ,  52.  ,  44.  , 100.  ,  90.  ,  77.  ,  37.  ,
#         70.  , 240.  ,  49.  ,  30.  ,  48.  ,  42.  ,  47.  ,  51.  ,
#         79.  ,  57.  ,  45.  , 102.  , 120.  ,  54.  , 168.  , 144.  ,
#         60.  ,  36.  ,  72.  , 114.  , 174.  ,  66.6 ,  38.  ,  84.6 ,
#         40.  ,  25.  ,  96.  ,  52.11,  15.  , 128.4 ,  66.  ,  74.4 ,
#        143.  ,  68.4 ,  78.  ,  85.2 , 121.8 , 142.2 ,  55.  ,  94.8 ,
#         26.  ,  70.2 ,  69.  ,  89.4 ,  93.6 ,  64.8 ,  61.2 ,  53.  ,
#         23.  ,  11.  ,  63.  ,  65.  ,  80.  ,  31.  ,  39.  ,  29.  ,
#         45.15,  33.9 ,  52.21,  41.  , 215.4 ,  79.8 ,  67.8 ,  92.4 ,
#         61.8 ,  70.8 ,  59.  , 180.  ,  72.6 , 138.  ,  81.  ,  80.4 ,
#         88.8 ,  63.6 ,  38.69,  34.  , 112.  , 137.  ,  58.  ,  94.  ,
# ...

# %%
df.replace({'42. 6':42.6 ,'32. 33': 32.33},inplace=True)

# %%
df['TMT A'] = df['TMT A'].astype(float)

# %%
df['TMT B'] = df['TMT B'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 0 to 832
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sr.No.       833 non-null    int64
#  1   Age          833 non-null    float64
#  2   Gender       833 non-null    object
#  3   Ht           833 non-null    float64
#  4   Wt           833 non-null    float64
#  5   Address      798 non-null    object
#  6   Med History  352 non-null    object
#  7   Sx History   450 non-null    object
#  8   Medication   342 non-null    object
#  9   HTN          583 non-null    object
#  10  DM           567 non-null    object
#  11  B.P.         717 non-null    object
#  12  Systolic     717 non-null    float64
#  13  Diastolic    717 non-null    float64
#  14  GDS          779 non-null    float64
#  15  MOCA         781 non-null    float64
#  16  PEFR 2       488 non-null    float64
#  17  MWT          606 non-null    float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df['Wt'])
# Out:
# <Axes: xlabel='Wt', ylabel='Density'>

# %%
df['Wt'].skew()
# Out:
# 0.6354683528983706

# %%
sns.distplot(df['Ht'])
# Out:
# <Axes: xlabel='Ht', ylabel='Density'>

# %%
df['Ht'].skew()
# Out:
# -0.10232408648424739

# %%
Continuous = []
Categorical = []

for i in df.columns:
    if df[i].dtypes==object:
        Categorical.append(i)
    else:
        Continuous.append(i)

# %%
Continuous
# Out:
# ['Sr.No.',
#  'Age',
#  'Ht',
#  'Wt',
#  'Systolic',
#  'Diastolic',
#  'GDS',
#  'MOCA',
#  'PEFR 2',
#  'MWT',
#  'TUG',
#  'FRT',
#  'TMT A',
#  'TMT B',
#  'OPQOL',
#  'QPAR']

# %%
Categorical
# Out:
# ['Gender',
#  'Address',
#  'Med History',
#  'Sx History',
#  'Medication',
#  'HTN',
#  'DM',
#  'B.P.']

# %%
df.drop(['Gender',
 'Address',
 'Med History',
 'Sx History',
 'Medication',
 'HTN',
 'DM',
 'B.P.'],axis=1,inplace=True)

# %%
corr = df.corr()
corr
# Out:
#              Sr.No.       Age        Ht        Wt  Systolic  Diastolic  \
# Sr.No.     1.000000  0.119929 -0.045030 -0.004528 -0.073760   0.063225
# Age        0.119929  1.000000  0.055492 -0.182239  0.163276  -0.125075
# Ht        -0.045030  0.055492  1.000000  0.432276  0.048591   0.023933
# Wt        -0.004528 -0.182239  0.432276  1.000000  0.042832   0.132141
# Systolic  -0.073760  0.163276  0.048591  0.042832  1.000000   0.434293
# Diastolic  0.063225 -0.125075  0.023933  0.132141  0.434293   1.000000
# GDS        0.062093  0.075476 -0.179242 -0.088960 -0.033794  -0.024353
# MOCA      -0.063180 -0.085447  0.101448  0.095964 -0.074810  -0.038173
# PEFR 2    -0.216910 -0.113625  0.340518  0.184476 -0.020030  -0.009042
# MWT       -0.051280 -0.044322  0.118536  0.056293  0.075964   0.099053
# TUG       -0.076927  0.156403  0.011296 -0.036709  0.013911  -0.067080
# FRT       -0.478092 -0.157253  0.106150  0.128830  0.105136  -0.037685
# ...

# %%
stats = df.describe()
stats
# Out:
#            Sr.No.         Age          Ht          Wt    Systolic   Diastolic  \
# count  833.000000  833.000000  833.000000  833.000000  717.000000  717.000000
# mean   417.000000   68.801200  158.073277   64.063637  142.536960   76.467364
# std    240.610681    7.411513    9.056235   10.917861   20.831804   11.752297
# min      1.000000   43.000000  101.000000   30.000000   93.000000    1.100000
# 25%    209.000000   64.000000  151.000000   57.000000  127.000000   70.000000
# 50%    417.000000   68.000000  158.000000   63.800000  142.000000   76.000000
# 75%    625.000000   73.000000  164.000000   70.000000  156.000000   83.000000
# max    833.000000   95.000000  185.000000  124.000000  213.000000  113.000000
#
#               GDS        MOCA      PEFR 2         MWT         TUG         FRT  \
# count  779.000000  781.000000  488.000000  606.000000  773.000000  725.000000
# mean     4.829268   24.064020  238.889344  118.463355   12.006453   20.689676
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
stats.to_excel('Geriatric Data Stats1.xlsx')

# %%
corr.to_excel('Geriatric Data Stats1.xlsx')

# %%
df.to_excel('Geriatric Data 1 .xlsx')

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'C:\Users\Sandesh\Project\Physiotherapy Project\Geriatric_Data.xlsx')
df
# Out:
#      Sr.No.   Age Gender      Ht     Wt        BMI     Fitness     Address  \
# 0         1  71.0      M  158.07  71.00  28.415771       Obese  Old Sangvi
# 1         2  62.0      F  150.00  72.00  32.000000       Obese  New Sangvi
# 2         3  68.0      M  158.07  60.00  24.013327  Overweight  New Sangvi
# 3         4  70.0      M  158.07  62.00  24.813772  Overweight  Old Sangvi
# 4         5  68.0      M  161.00  63.00  24.304618  Overweight  Old Sangvi
# ..      ...   ...    ...     ...    ...        ...         ...         ...
# 828     829  67.0      F  153.00  61.00  26.058354       Obese     Bavdhan
# 829     830  82.0      M  158.07  64.06  25.638229       Obese     Bavdhan
# 830     831  85.0      F  156.00  67.00  27.531229       Obese     Bavdhan
# 831     832  74.0      M  163.00  58.00  21.829952      Normal     Bavdhan
# 832     833  81.0      F  147.00  60.00  27.766209       Obese     Bavdhan
#
# ...

# %%
Continuous = []
Categorical = []

for i in df.columns:
    if df[i].dtypes==object:
        Categorical.append(i)
    else:
        Continuous.append(i)

# %%
Categorical
# Out:
# ['Gender',
#  'Fitness',
#  'Address',
#  'Med History',
#  'Sx History',
#  'Medication',
#  'HTN',
#  'DM',
#  'B.P.']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 0 to 832
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sr.No.       833 non-null    int64
#  1   Age          833 non-null    float64
#  2   Gender       833 non-null    object
#  3   Ht           833 non-null    float64
#  4   Wt           833 non-null    float64
#  5   BMI          833 non-null    float64
#  6   Fitness      833 non-null    object
#  7   Address      798 non-null    object
#  8   Med History  352 non-null    object
#  9   Sx History   450 non-null    object
#  10  Medication   342 non-null    object
#  11  HTN          583 non-null    object
#  12  DM           567 non-null    object
#  13  B.P.         717 non-null    object
#  14  Systolic     717 non-null    float64
#  15  Diastolic    717 non-null    float64
#  16  GDS          779 non-null    float64
#  17  MOCA         781 non-null    float64
# ...

# %%
df.drop(['Gender','Sr.No.','Fitness','Systolic','Diastolic',
 'Address',
 'Med History',
 'Sx History',
 'Medication',
 'HTN',
 'DM',
 'B.P.'],axis=1,inplace=True)

# %%
corr = df.corr()
corr
# Out:
#              Age        Ht        Wt       BMI       GDS      MOCA    PEFR 2  \
# Age     1.000000  0.055492 -0.182239 -0.230750  0.075476 -0.085447 -0.113625
# Ht      0.055492  1.000000  0.432276 -0.274546 -0.179242  0.101448  0.340518
# Wt     -0.182239  0.432276  1.000000  0.739170 -0.088960  0.095964  0.184476
# BMI    -0.230750 -0.274546  0.739170  1.000000  0.038375  0.020209 -0.061074
# GDS     0.075476 -0.179242 -0.088960  0.038375  1.000000 -0.209001 -0.108225
# MOCA   -0.085447  0.101448  0.095964  0.020209 -0.209001  1.000000  0.145430
# PEFR 2 -0.113625  0.340518  0.184476 -0.061074 -0.108225  0.145430  1.000000
# MWT    -0.044322  0.118536  0.056293 -0.037426 -0.121596  0.003299 -0.086438
# TUG     0.156403  0.011296 -0.036709 -0.042538  0.071546  0.023068 -0.043670
# FRT    -0.157253  0.106150  0.128830  0.059638 -0.111026  0.148992  0.077415
# TMT A   0.186246 -0.164456 -0.131171 -0.026026  0.177603 -0.060060 -0.170402
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
corr.to_excel('Geriatric Data Stats1.xlsx')
