# %%
import pandas as pd
import numpy as np

# %%
r'C:\Users\Sandesh\Physiotherapy Project\Geriatric data_6-12-23.xlsx'
# Out:
# 'C:\\Users\\Sandesh\\Physiotherapy Project\\Geriatric data_6-12-23.xlsx'

# %%
df = pd.read_excel(r'C:\Users\Sandesh\Project\Physiotherapy Project\Geriatric Data 6-12-23.xlsx')
df
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4        Unnamed: 5  \
# 0          NaN        NaN        NaN        NaN        NaN               NaN
# 1          NaN        NaN        NaN        NaN        NaN               NaN
# 2          NaN        NaN        NaN        NaN        NaN               NaN
# 3      Sr. No.        Age     Gender         Ht         Wt           Address
# 4            1         71         M         NaN         71  Old Sangvi, Pune
# ..         ...        ...        ...        ...        ...               ...
# 832        829         67          F        153         61  Athashri Pebbles
# 833        830         82          M        NaN        NaN  Athashri Pebbles
# 834        831         85          F        156         67  Athashri Pebbles
# 835        832         74          M        163         58  Athashri Pebbles
# 836        833         81          F        147         60  Athashri Pebbles
#
# ...

# %%
df.drop([0,1,2,3],inplace=True)

# %%
df
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4        Unnamed: 5  \
# 4            1         71         M         NaN         71  Old Sangvi, Pune
# 5            2         62          F        150         72  New Sangvi, Pune
# 6            3         68          M        NaN         60  New Sangvi, Pune
# 7            4         70         M         NaN         62  Old Sangvi, Pune
# 8            5         68          M        161         63  Old Sangvi, Pune
# ..         ...        ...        ...        ...        ...               ...
# 832        829         67          F        153         61  Athashri Pebbles
# 833        830         82          M        NaN        NaN  Athashri Pebbles
# 834        831         85          F        156         67  Athashri Pebbles
# 835        832         74          M        163         58  Athashri Pebbles
# 836        833         81          F        147         60  Athashri Pebbles
#
# ...

# %%
df.columns=['Sr.No.','Age','Gender','Ht','Wt','Address','Med History','Sx History','medication','HTN','DM','B.P','GDS','MOCA','PEFR 2','MWT','TUG','FRT','TMT A','TMT B','OPQOL','QPAR']

# %%
df.index = range(1,834)

# %%
df
# Out:
#     Sr.No. Age Gender   Ht   Wt           Address  \
# 1        1  71     M   NaN   71  Old Sangvi, Pune
# 2        2  62      F  150   72  New Sangvi, Pune
# 3        3  68      M  NaN   60  New Sangvi, Pune
# 4        4  70     M   NaN   62  Old Sangvi, Pune
# 5        5  68      M  161   63  Old Sangvi, Pune
# ..     ...  ..    ...  ...  ...               ...
# 829    829  67      F  153   61  Athashri Pebbles
# 830    830  82      M  NaN  NaN  Athashri Pebbles
# 831    831  85      F  156   67  Athashri Pebbles
# 832    832  74      M  163   58  Athashri Pebbles
# 833    833  81      F  147   60  Athashri Pebbles
#
#                                            Med History  \
# 1                                bp,dm, Neck pain, LBP
# 2                                                  NaN
# 3                     BP since 10 yrs, DM since 15 yrs
# 4    Ulcer, Appendisectomy, Hernioplasty, B/L cataract
# 5                             DM since 1.5 years, OAKJ
# ...

# %%
df.isna().sum()
# Out:
# Sr.No.           0
# Age              3
# Gender           1
# Ht              30
# Wt               9
# Address         33
# Med History    488
# Sx History     383
# medication     491
# HTN            250
# DM             266
# B.P            113
# GDS             53
# MOCA            47
# PEFR 2         337
# MWT            220
# TUG             49
# FRT            102
# TMT A          262
# TMT B          308
# OPQOL          741
# QPAR           740
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 1 to 833
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sr.No.       833 non-null    object
#  1   Age          830 non-null    object
#  2   Gender       832 non-null    object
#  3   Ht           803 non-null    object
#  4   Wt           824 non-null    object
#  5   Address      800 non-null    object
#  6   Med History  345 non-null    object
#  7   Sx History   450 non-null    object
#  8   medication   342 non-null    object
#  9   HTN          583 non-null    object
#  10  DM           567 non-null    object
#  11  B.P          720 non-null    object
#  12  GDS          780 non-null    object
#  13  MOCA         786 non-null    object
#  14  PEFR 2       496 non-null    object
#  15  MWT          613 non-null    object
#  16  TUG          784 non-null    object
#  17  FRT          731 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Sr.No.', 'Age', 'Gender', 'Ht', 'Wt', 'Address', 'Med History',
#        'Sx History', 'medication', 'HTN', 'DM', 'B.P', 'GDS', 'MOCA', 'PEFR 2',
#        'MWT', 'TUG', 'FRT', 'TMT A', 'TMT B', 'OPQOL', 'QPAR'],
#       dtype='object')

# %%
#df.drop(['Address','Med History','Sx History','medication','PEFR 2','TMT A','TMT B'],inplace=True, axis=1)

# %%
df
# Out:
#     Sr.No. Age Gender   Ht   Wt           Address  \
# 1        1  71     M   NaN   71  Old Sangvi, Pune
# 2        2  62      F  150   72  New Sangvi, Pune
# 3        3  68      M  NaN   60  New Sangvi, Pune
# 4        4  70     M   NaN   62  Old Sangvi, Pune
# 5        5  68      M  161   63  Old Sangvi, Pune
# ..     ...  ..    ...  ...  ...               ...
# 829    829  67      F  153   61  Athashri Pebbles
# 830    830  82      M  NaN  NaN  Athashri Pebbles
# 831    831  85      F  156   67  Athashri Pebbles
# 832    832  74      M  163   58  Athashri Pebbles
# 833    833  81      F  147   60  Athashri Pebbles
#
#                                            Med History  \
# 1                                bp,dm, Neck pain, LBP
# 2                                                  NaN
# 3                     BP since 10 yrs, DM since 15 yrs
# 4    Ulcer, Appendisectomy, Hernioplasty, B/L cataract
# 5                             DM since 1.5 years, OAKJ
# ...

# %%
df.columns
# Out:
# Index(['Sr.No.', 'Age', 'Gender', 'Ht', 'Wt', 'Address', 'Med History',
#        'Sx History', 'medication', 'HTN', 'DM', 'B.P', 'GDS', 'MOCA', 'PEFR 2',
#        'MWT', 'TUG', 'FRT', 'TMT A', 'TMT B', 'OPQOL', 'QPAR'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

import warnings
warnings.filterwarnings('ignore')

# %%
df['Gender'].unique()
# Out:
# array(['M ', 'F', 'M', nan, 'F      '], dtype=object)

# %%
df.replace({'M ':'M','F      ':'F',},inplace=True)

# %%
df['Gender'].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
df['Gender'].mode()
# Out:
# 0    F
# Name: Gender, dtype: object

# %%
df['Gender'].fillna('F',inplace=True)

# %%
sns.countplot(data=df,x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    424
# M    409
# Name: count, dtype: int64

# %%
df['Age']=df['Age'].astype('float')

# %%
df['Age'].mean()
# Out:
# 68.8012048192771

# %%
df['Age'].fillna(68.8,inplace=True)

# %%
df.isna().sum()
# Out:
# Sr.No.           0
# Age              0
# Gender           0
# Ht              30
# Wt               9
# Address         33
# Med History    488
# Sx History     383
# medication     491
# HTN            250
# DM             266
# B.P            113
# GDS             53
# MOCA            47
# PEFR 2         337
# MWT            220
# TUG             49
# FRT            102
# TMT A          262
# TMT B          308
# OPQOL          741
# QPAR           740
# dtype: int64

# %%
sns.distplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df['Age'].skew()
# Out:
# 0.15020676533780647

# %%
df['Ht']=df['Ht'].astype('float')

# %%
df['Ht'].mean()
# Out:
# 158.073399750934

# %%
df['Ht'].fillna(158.07,inplace=True)

# %%
df.isna().sum()
# Out:
# Sr.No.           0
# Age              0
# Gender           0
# Ht               0
# Wt               9
# Address         33
# Med History    488
# Sx History     383
# medication     491
# HTN            250
# DM             266
# B.P            113
# GDS             53
# MOCA            47
# PEFR 2         337
# MWT            220
# TUG             49
# FRT            102
# TMT A          262
# TMT B          308
# OPQOL          741
# QPAR           740
# dtype: int64

# %%
sns.distplot(df['Ht'])
# Out:
# <Axes: xlabel='Ht', ylabel='Density'>

# %%
df['Ht'].skew()
# Out:
# -0.10232408648424737

# %%
df['Ht'].mode()
# Out:
# 0    160.0
# Name: Ht, dtype: float64

# %%
df['Ht'].median()
# Out:
# 158.0

# %%
df['Ht'].mean()
# Out:
# 158.07327731092434

# %%
df['Wt'].unique()
# Out:
# array([71, 72, 60, 62, 63, 55, 53, 56, 81, 100, 65, 57, 68, 78, 46, 61,
#        66, 54, 58, 79, 48, 76, 84, 69, 85, 35, 74, 40, 67, 75, 77, 70, 93,
#        59, 47, 80, 61.5, 64, nan, 50, 51, 88, 52, 97, 87, 49, 73, 86, 94,
#        45, 82, 30, 43, 67.5, 88.5, 83, 42, 99, 95, '  ', 89, 44, 48.5,
#        51.4, 81.7, 66.1, 63.8, 74.6, 64.9, 65.7, 77.3, 69.9, 67.3, 57.7,
#        56.7, 51.5, 57.05, 60.8, 39.8, 45.8, 98.7, 72.2, 63.5, 69.2, 58.8,
#        61.2, 68.5, 62.5, 33.9, 52.1, 47.9, 56.5, 60.5, 90, 70.5, 64.5,
#        '68', '71', '54', '51', '56', '65', '73', '75', '61', '69', '120',
#        '60', '62', '79', '44', '59', 61.8, '57', '105', '64', '55', '70',
#        '58', '86', '63', '45', '50', '35', '53', '47', '80', '124', '76',
#        '67'], dtype=object)

# %%
df['Wt'].replace({'  ':None,'68':68,'71':71,'54':54,'51':51,'56':56,'65':65,'73':73,'75':75,'61':61,'69':69,'120':120,'60':60,'62':62,'79':79,'44':44,'59':59,'61.8':61.8,'57':57,'105':105,'64':64,'55':55,'70':70,'58':58,'86':86,'63':63,'45':45,'50':50,'35':35,'53':53,'47':47,'80':80,'124':124,'76':76,'67':67},inplace=True)

# %%
df['Wt'].unique()
# Out:
# array([ 71.  ,  72.  ,  60.  ,  62.  ,  63.  ,  55.  ,  53.  ,  56.  ,
#         81.  , 100.  ,  65.  ,  57.  ,  68.  ,  78.  ,  46.  ,  61.  ,
#         66.  ,  54.  ,  58.  ,  79.  ,  48.  ,  76.  ,  84.  ,  69.  ,
#         85.  ,  35.  ,  74.  ,  40.  ,  67.  ,  75.  ,  77.  ,  70.  ,
#         93.  ,  59.  ,  47.  ,  80.  ,  61.5 ,  64.  ,    nan,  50.  ,
#         51.  ,  88.  ,  52.  ,  97.  ,  87.  ,  49.  ,  73.  ,  86.  ,
#         94.  ,  45.  ,  82.  ,  30.  ,  43.  ,  67.5 ,  88.5 ,  83.  ,
#         42.  ,  99.  ,  95.  ,  89.  ,  44.  ,  48.5 ,  51.4 ,  81.7 ,
#         66.1 ,  63.8 ,  74.6 ,  64.9 ,  65.7 ,  77.3 ,  69.9 ,  67.3 ,
#         57.7 ,  56.7 ,  51.5 ,  57.05,  60.8 ,  39.8 ,  45.8 ,  98.7 ,
#         72.2 ,  63.5 ,  69.2 ,  58.8 ,  61.2 ,  68.5 ,  62.5 ,  33.9 ,
#         52.1 ,  47.9 ,  56.5 ,  60.5 ,  90.  ,  70.5 ,  64.5 , 120.  ,
#         61.8 , 105.  , 124.  ])

# %%
array = df['Wt'].unique()
pd.Series(array)
# Out:
# 0      71.0
# 1      72.0
# 2      60.0
# 3      62.0
# 4      63.0
#       ...
# 94     64.5
# 95    120.0
# 96     61.8
# 97    105.0
# 98    124.0
# Length: 99, dtype: float64

# %%
df['Wt'].mean()
# Out:
# 64.06368613138686

# %%
df['Wt'].fillna(64.06,inplace=True)

# %%
df.isna().sum()
# Out:
# Sr.No.           0
# Age              0
# Gender           0
# Ht               0
# Wt               0
# Address         33
# Med History    488
# Sx History     383
# medication     491
# HTN            250
# DM             266
# B.P            113
# GDS             53
# MOCA            47
# PEFR 2         337
# MWT            220
# TUG             49
# FRT            102
# TMT A          262
# TMT B          308
# OPQOL          741
# QPAR           740
# dtype: int64

# %%
sns.distplot(df['Wt'])
# Out:
# <Axes: xlabel='Wt', ylabel='Density'>

# %%
df['Wt'].skew()
# Out:
# 0.6354683528983706

# %%
df['Wt'].mean()
# Out:
# 64.06363745498199

# %%
df['Wt'].mode()
# Out:
# 0    60.0
# Name: Wt, dtype: float64

# %%
df['Wt'].median()
# Out:
# 63.8

# %%
df['HTN'].value_counts()
# Out:
# HTN
# YES    344
# NO     239
# Name: count, dtype: int64

# %%
df['HTN'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data=df,x='HTN')
# Out:
# <Axes: xlabel='HTN', ylabel='count'>

# %%
df['DM'].value_counts()
# Out:
# DM
# NO     331
# YES    236
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='DM')
# Out:
# <Axes: xlabel='DM', ylabel='count'>

# %%
df['GDS'].unique()
# Out:
# array([7, 1, 5, 2, 9, nan, 3, 4, 10, 6, 8, 0, 12, 14, 13, 11, 16, 19, 17,
#        20, 25, 21, 15, 18, ' ', 28, 22, '1', '5', '4', '13', '3', '10',
#        '17', 23, '0', '6', '2', 24, '8', '7', '25', '18', '19', '12',
#        '15', '11'], dtype=object)

# %%
df['GDS'].replace({'1':1,'5':5,'4':4,'13':13,'3':3,'10':10,'17':17,'0':0,'6':6,'2':2,'8':8,'7':7,'25':25,'18':18,'19':19,'12':12,'15':15,'11':11,' ':None,'nan':None},inplace=True)

# %%
df['GDS'].unique()
# Out:
# array([ 7.,  1.,  5.,  2.,  9., nan,  3.,  4., 10.,  6.,  8.,  0., 12.,
#        14., 13., 11., 16., 19., 17., 20., 25., 21., 15., 18., 28., 22.,
#        23., 24.])

# %%
array = df['GDS'].unique()
pd.Series(array)
# Out:
# 0      7.0
# 1      1.0
# 2      5.0
# 3      2.0
# 4      9.0
# 5      NaN
# 6      3.0
# 7      4.0
# 8     10.0
# 9      6.0
# 10     8.0
# 11     0.0
# 12    12.0
# 13    14.0
# 14    13.0
# 15    11.0
# 16    16.0
# 17    19.0
# 18    17.0
# 19    20.0
# 20    25.0
# 21    21.0
# 22    15.0
# 23    18.0
# 24    28.0
# 25    22.0
# 26    23.0
# 27    24.0
# dtype: float64

# %%
sns.distplot(df['GDS'])
# Out:
# <Axes: xlabel='GDS', ylabel='Density'>

# %%
df['GDS'].skew()
# Out:
# 1.5751893618476618

# %%
df['GDS'].mean()
# Out:
# 4.829268292682927

# %%
df['GDS'].mode()
# Out:
# 0    0.0
# Name: GDS, dtype: float64

# %%
df['GDS'].median()
# Out:
# 3.0

# %%
df['GDS'].value_counts()
# Out:
# GDS
# 0.0     138
# 2.0      99
# 3.0      82
# 1.0      78
# 4.0      69
# 5.0      52
# 6.0      47
# 7.0      42
# 8.0      36
# 10.0     23
# 9.0      19
# 12.0     18
# 13.0     16
# 11.0     11
# 15.0     10
# 19.0      7
# 17.0      6
# 14.0      5
# 16.0      4
# 25.0      4
# 21.0      4
# 18.0      3
# 20.0      2
# 28.0      1
# 22.0      1
# 23.0      1
# 24.0      1
# Name: count, dtype: int64

# %%
df['GDS'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='GDS'>

# %%
df['MOCA'].unique()
# Out:
# array([27, 30, 18, 21, 24, nan, 25, 29, 28, 20, 22, 26, 17, 12, 23, 19,
#        16, 6, 9, 15, 14, 2, 13, 5, '  ', 7, 1, 4, 0, 3, 8, 11, '18', '27',
#        '26', '28', '21', '30', '22', '29', '24', '19', '14', '20', '23',
#        '25', '17', '11'], dtype=object)

# %%
df['MOCA'].replace({'  ':None,'18':18,'27':27,'26':26,'28':28,'21':21,'30':30,'22':22,'29':29,'24':24,'19':19,'14':14,'20':20,'23':23,'25':25,'17':17,'11':11},inplace=True)

# %%
df['MOCA'].unique()
# Out:
# array([27., 30., 18., 21., 24., nan, 25., 29., 28., 20., 22., 26., 17.,
#        12., 23., 19., 16.,  6.,  9., 15., 14.,  2., 13.,  5.,  7.,  1.,
#         4.,  0.,  3.,  8., 11.])

# %%
array = df['MOCA'].unique()
pd.Series(array)
# Out:
# 0     27.0
# 1     30.0
# 2     18.0
# 3     21.0
# 4     24.0
# 5      NaN
# 6     25.0
# 7     29.0
# 8     28.0
# 9     20.0
# 10    22.0
# 11    26.0
# 12    17.0
# 13    12.0
# 14    23.0
# 15    19.0
# 16    16.0
# 17     6.0
# 18     9.0
# 19    15.0
# 20    14.0
# 21     2.0
# 22    13.0
# 23     5.0
# 24     7.0
# 25     1.0
# 26     4.0
# 27     0.0
# 28     3.0
# 29     8.0
# 30    11.0
# dtype: float64

# %%
sns.distplot(df['MOCA'])
# Out:
# <Axes: xlabel='MOCA', ylabel='Density'>

# %%
df['MOCA'].skew()
# Out:
# -2.110212166200407

# %%
df['MOCA'].mean()
# Out:
# 24.064020486555698

# %%
df['MOCA'].median()
# Out:
# 25.0

# %%
df['MOCA'].mode()
# Out:
# 0    26.0
# Name: MOCA, dtype: float64

# %%
df['MOCA'].value_counts()
# Out:
# MOCA
# 26.0    101
# 27.0     94
# 28.0     90
# 25.0     82
# 24.0     65
# 29.0     57
# 23.0     53
# 22.0     41
# 30.0     37
# 20.0     35
# 21.0     30
# 19.0     14
# 16.0     14
# 18.0     13
# 17.0     10
# 14.0      7
# 15.0      6
# 12.0      5
# 1.0       5
# 13.0      4
# 2.0       3
# 0.0       3
# 5.0       2
# 4.0       2
# 8.0       2
# 11.0      2
# 9.0       1
# 7.0       1
# 6.0       1
# 3.0       1
# Name: count, dtype: int64

# %%
df['MOCA'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='MOCA'>

# %%
df.isna().sum()
# Out:
# Sr.No.           0
# Age              0
# Gender           0
# Ht               0
# Wt               0
# Address         33
# Med History    488
# Sx History     383
# medication     491
# HTN            250
# DM             266
# B.P            113
# GDS             54
# MOCA            52
# PEFR 2         337
# MWT            220
# TUG             49
# FRT            102
# TMT A          262
# TMT B          308
# OPQOL          741
# QPAR           740
# dtype: int64

# %%
df['TUG'].unique()
# Out:
# array([18, 14.8, 15.5, 12.4, 14.6, 19.5, 12.5, 10, 9.6, 14.5, 15, 10.8,
#        10.5, 14, 12.2, 16, 11, 9, 12, 13, 15.3, 11.2, 10.3, 10.9, 11.5,
#        12.9, 14.4, nan, 10.2, 8, 12.3, 9.5, 11.4, 10.4, 20.6, 16.3, 11.8,
#        27, 17, 12.7, 12.6, 21, 11.7, 13.7, 19, 13.9, 8.6, 10.55, 11.75,
#        9.7, 13.2, 8.3, 11.33, 9.8, 8.9, 8.8, 155, 9.9, 10.56, 7, 8.7, 5.5,
#        19.56, 12.29, 11.69, 10.67, 11.53, 13.44, 10.57, 112, 12.86, 14.9,
#        12.95, 7.2, 14.45, 7.1, 22, 7.3, 9.2, 14.3, 13.5, 11.6, 13.8, 10.7,
#        8.2, 19.6, 10.29, 5.54, 12.8, 9.4, 17.7, 74, 8.26, 8.4, 10.6, 15.2,
#        25, 9.55, 9.1, 11.1, 9.12, 20.2, 6, '  ', 14.19, 16.1, 8.83, 13.59,
#        9.49, 12.41, 11.59, 8.93, 13.29, 9.36, 13.13, 9.13, 13.4, 9.17,
#        17.37, 12.64, 9.45, 8.17, 19.73, 10.01, 11.57, 9.66, 9.84, 11.398,
#        8.53, 9.53, 7.6, 8.79, 8.37, 11.43, 8.68, 7.15, 13.06, 21.33,
#        12.32, 12.07, 8.95, 8.65, 12.42, 8.41, 15.54, 9.22, 7.89, 7.53, 91,
# ...

# %%
df['TUG'].replace({'8.2':8.2, '7.1':7.1, '5.9':5.9, '5.8':5.8, '15.2':15.2, '10.1':10.1,'12.6':12.6, '9.1':9.1, '806':806, '7.4':7.4, '8.4':8.4, '7.1 ':7.1, '6.2':6.2, '6.1':6.1, '6':6,
       '8.3':8.3, '12':12, '7.6':7.6, '12. 72 ':12.72,  '12.84':12.84,'12.87':12.87, '16':16,  '13.53 ':13.53,'13.48 ':13.48, '11.40':11.40, '11.33':11.33, '9':9, '13.96':13.96, '45':45, '11.61':11.61,
        '13.4':13.4, '8':8, '17':17, '13':13, '10.35':10.35, '10.43':10.43, '8.79':8.79, '10':10, '19.84':19.84, '19.30':19.30, '8.19':8.19, '7.47':7.74, '8.73':8.73, '9.19':9.19, '8.20':8.20,
       '8.91':8.91, '12.85':12.85, '8.92':8.92, '14.64':14.64,'  ':None,'8.6':8.6},inplace=True)

# %%
df['TUG'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 833 entries, 1 to 833
# Series name: TUG
# Non-Null Count  Dtype
# --------------  -----
# 773 non-null    float64
# dtypes: float64(1)
# memory usage: 6.6 KB

# %%
sns.distplot(df['TUG'])
# Out:
# <Axes: xlabel='TUG', ylabel='Density'>

# %%
df['TUG'].skew()
# Out:
# 10.982342528908706

# %%
df['TUG'].mean()
# Out:
# 12.006452781371282

# %%
df['TUG'].mode()
# Out:
# 0    10.0
# Name: TUG, dtype: float64

# %%
sns.scatterplot(data=df,x='Wt',y='Ht')
# Out:
# <Axes: xlabel='Wt', ylabel='Ht'>

# %%
sns.scatterplot(data=df,x='Age',y='GDS')
# Out:
# <Axes: xlabel='Age', ylabel='GDS'>

# %%
sns.scatterplot(data=df,x='Ht',y='GDS')
# Out:
# <Axes: xlabel='Ht', ylabel='GDS'>

# %%
sns.scatterplot(data=df,x='Wt',y='GDS')
# Out:
# <Axes: xlabel='Wt', ylabel='GDS'>

# %%
sns.scatterplot(data=df,x='Ht',y='MOCA')
# Out:
# <Axes: xlabel='Ht', ylabel='MOCA'>

# %%
sns.scatterplot(data=df,x='Wt',y='MOCA')
# Out:
# <Axes: xlabel='Wt', ylabel='MOCA'>

# %%
sns.scatterplot(data=df,x='Age',y='MOCA')
# Out:
# <Axes: xlabel='Age', ylabel='MOCA'>

# %%
sns.scatterplot(data=df,x='GDS',y='MOCA')
# Out:
# <Axes: xlabel='GDS', ylabel='MOCA'>

# %%
sns.countplot(data=df,x='Gender',hue='GDS')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df,x='Gender',hue='MOCA')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.scatterplot(data=df,x='TUG',y='Ht')
# Out:
# <Axes: xlabel='TUG', ylabel='Ht'>

# %%
sns.scatterplot(data=df,x='TUG',y='Wt')
# Out:
# <Axes: xlabel='TUG', ylabel='Wt'>

# %%
sns.scatterplot(data=df,x='TUG',y='Age')
# Out:
# <Axes: xlabel='TUG', ylabel='Age'>

# %%
sns.boxplot(data=df,x='Gender',y='TUG')
# Out:
# <Axes: xlabel='Gender', ylabel='TUG'>

# %%
sns.scatterplot(data=df,x='TUG',y='GDS')
# Out:
# <Axes: xlabel='TUG', ylabel='GDS'>

# %%
sns.scatterplot(data=df,x='TUG',y='MOCA')
# Out:
# <Axes: xlabel='TUG', ylabel='MOCA'>

# %%
sns.countplot(data=df,x='Gender',hue='DM')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.groupby('Gender')['DM'].value_counts()
# Out:
# Gender  DM
# F       NO     175
#         YES    114
# M       NO     156
#         YES    122
# Name: count, dtype: int64

# %%
df['DM'].value_counts()
# Out:
# DM
# NO     331
# YES    236
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='Gender',hue='HTN')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.groupby('Gender')['HTN'].value_counts()
# Out:
# Gender  HTN
# F       YES    185
#         NO     112
# M       YES    159
#         NO     127
# Name: count, dtype: int64

# %%
df['HTN'].value_counts()
# Out:
# HTN
# YES    344
# NO     239
# Name: count, dtype: int64

# %%
df[['Age','Ht','Wt','GDS','MOCA','TUG']].corr()
# Out:
#            Age        Ht        Wt       GDS      MOCA       TUG
# Age   1.000000  0.055492 -0.182239  0.075476 -0.085447  0.156403
# Ht    0.055492  1.000000  0.432276 -0.179242  0.101448  0.011296
# Wt   -0.182239  0.432276  1.000000 -0.088960  0.095964 -0.036709
# GDS   0.075476 -0.179242 -0.088960  1.000000 -0.209001  0.071546
# MOCA -0.085447  0.101448  0.095964 -0.209001  1.000000  0.023068
# TUG   0.156403  0.011296 -0.036709  0.071546  0.023068  1.000000

# %%
sns.boxplot(data=df,x='Gender',y='GDS')
# Out:
# <Axes: xlabel='Gender', ylabel='GDS'>

# %%
sns.boxplot(data=df,x='Gender',y='MOCA')
# Out:
# <Axes: xlabel='Gender', ylabel='MOCA'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 1 to 833
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sr.No.       833 non-null    int64
#  1   Age          833 non-null    float64
#  2   Gender       833 non-null    object
#  3   Ht           833 non-null    float64
#  4   Wt           833 non-null    float64
#  5   Address      800 non-null    object
#  6   Med History  345 non-null    object
#  7   Sx History   450 non-null    object
#  8   medication   342 non-null    object
#  9   HTN          583 non-null    object
#  10  DM           567 non-null    object
#  11  B.P          720 non-null    object
#  12  GDS          779 non-null    float64
#  13  MOCA         781 non-null    float64
#  14  PEFR 2       496 non-null    object
#  15  MWT          613 non-null    object
#  16  TUG          773 non-null    float64
#  17  FRT          731 non-null    object
# ...

# %%
df['MWT'].unique()
# Out:
# array([95, 97.1, 139, nan, 106, 81, 81.9, 150, 182, 122, 91, 127.4, 118,
#        113.7, 109, 94.5, 109.2, 167, 122.8, 95.5, 136.5, 120.8, 104.5,
#        76.5, 104, 100, 156.5, 133, 141, 114, 85.5, 142.5, 72, 130, 140,
#        120, 90, 168, 178, 174, 179, 105, 155, 173, 110, 125, 160, 135,
#        145, 80, 115, 65, 85, 175.2, 170, 127, 158, 160.5, 153, 126, 166,
#        140.2, 146, 144, 163.2, 130.5, 132, 99, 122.72, 145.28, 155.38,
#        157, 117.84, 134, 121.5, 114.73, 92.71, 178.64, 194.47, 136.113,
#        152, 146.34, 166.5, 177.55, 180, 164.13, 133.37, 168.94, 127.1,
#        131.08, 175.5, 186.72, 72.2, 115.82, 25, 57.31, 22, 68.08, 42, 39,
#        48, 219, 43.5, 65.25, 62.55, 38.06, 62.8, 55.4, 62, 55.7, 37.3, 44,
#        24.3, 36.4, 45, 56, 40, 51, 57, 76, 64.31, 38, 41, 58, 35, 43, 28,
#        34, 47, 33, 46.4, 46, 131, 165, 136, 113, 98, 156, 142, 89, 128,
#        108, 207, 149, 77, 138, 189, 161, 148, 119, 209, 124, 71, 74.5, 70,
# ...

# %%
df['MWT'].replace({'  ':None,' ':None},inplace=True)

# %%
df['MWT'].replace({'None':'nan'},inplace=True)

# %%
df['MWT'].unique()
# Out:
# array([ 95.   ,  97.1  , 139.   ,     nan, 106.   ,  81.   ,  81.9  ,
#        150.   , 182.   , 122.   ,  91.   , 127.4  , 118.   , 113.7  ,
#        109.   ,  94.5  , 109.2  , 167.   , 122.8  ,  95.5  , 136.5  ,
#        120.8  , 104.5  ,  76.5  , 104.   , 100.   , 156.5  , 133.   ,
#        141.   , 114.   ,  85.5  , 142.5  ,  72.   , 130.   , 140.   ,
#        120.   ,  90.   , 168.   , 178.   , 174.   , 179.   , 105.   ,
#        155.   , 173.   , 110.   , 125.   , 160.   , 135.   , 145.   ,
#         80.   , 115.   ,  65.   ,  85.   , 175.2  , 170.   , 127.   ,
#        158.   , 160.5  , 153.   , 126.   , 166.   , 140.2  , 146.   ,
#        144.   , 163.2  , 130.5  , 132.   ,  99.   , 122.72 , 145.28 ,
#        155.38 , 157.   , 117.84 , 134.   , 121.5  , 114.73 ,  92.71 ,
#        178.64 , 194.47 , 136.113, 152.   , 146.34 , 166.5  , 177.55 ,
#        180.   , 164.13 , 133.37 , 168.94 , 127.1  , 131.08 , 175.5  ,
# ...

# %%
sns.distplot(df['MWT'])
# Out:
# <Axes: xlabel='MWT', ylabel='Density'>

# %%
df['MWT'].skew()
# Out:
# 3.276112228197445

# %%
df['MWT'].mean()
# Out:
# 118.46335478547856

# %%
df['MWT'].mode()
# Out:
# 0    140.0
# Name: MWT, dtype: float64

# %%
df['MWT'].median()
# Out:
# 119.0

# %%
sns.boxplot(data=df,x='Gender',y='MWT')
# Out:
# <Axes: xlabel='Gender', ylabel='MWT'>

# %%
sns.scatterplot(data=df,x='MWT',y='TUG',hue='Gender')
# Out:
# <Axes: xlabel='MWT', ylabel='TUG'>

# %%
sns.scatterplot(data=df,x='MWT',y='GDS')
# Out:
# <Axes: xlabel='MWT', ylabel='GDS'>

# %%
sns.scatterplot(data=df,x='MWT',y='MOCA')
# Out:
# <Axes: xlabel='MWT', ylabel='MOCA'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 1 to 833
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sr.No.       833 non-null    int64
#  1   Age          833 non-null    float64
#  2   Gender       833 non-null    object
#  3   Ht           833 non-null    float64
#  4   Wt           833 non-null    float64
#  5   Address      800 non-null    object
#  6   Med History  345 non-null    object
#  7   Sx History   450 non-null    object
#  8   medication   342 non-null    object
#  9   HTN          583 non-null    object
#  10  DM           567 non-null    object
#  11  B.P          720 non-null    object
#  12  GDS          779 non-null    float64
#  13  MOCA         781 non-null    float64
#  14  PEFR 2       496 non-null    object
#  15  MWT          606 non-null    float64
#  16  TUG          773 non-null    float64
#  17  FRT          731 non-null    object
# ...

# %%
df
# Out:
#      Sr.No.   Age Gender      Ht     Wt           Address  \
# 1         1  71.0      M  158.07  71.00  Old Sangvi, Pune
# 2         2  62.0      F  150.00  72.00  New Sangvi, Pune
# 3         3  68.0      M  158.07  60.00  New Sangvi, Pune
# 4         4  70.0      M  158.07  62.00  Old Sangvi, Pune
# 5         5  68.0      M  161.00  63.00  Old Sangvi, Pune
# ..      ...   ...    ...     ...    ...               ...
# 829     829  67.0      F  153.00  61.00  Athashri Pebbles
# 830     830  82.0      M  158.07  64.06  Athashri Pebbles
# 831     831  85.0      F  156.00  67.00  Athashri Pebbles
# 832     832  74.0      M  163.00  58.00  Athashri Pebbles
# 833     833  81.0      F  147.00  60.00  Athashri Pebbles
#
#                                            Med History  \
# 1                                bp,dm, Neck pain, LBP
# 2                                                  NaN
# 3                     BP since 10 yrs, DM since 15 yrs
# ...

# %%
df.to_excel('Geriatric_Data.xlsx')
